# %% [markdown]
# ---
# Project for the course in Microeconometrics | Summer 2020, M.Sc. Economics, Bonn University | [Federico Alexander Rizzuto](https://github.com/FedericoAlexanderRizzuto)
#
# # Replication of Joshua D. Angrist, Erich Battistin, and Daniela Vuri  (2017) <a class="tocSkip">
# ---

# %% [markdown]
# This notebook contains my replication of the results from the following paper:
#
# > Angrist, J. D., Battistin, E., and Vuri, D. (2017). In a small moment: Class size and moral hazard in the Italian Mezzogiorno. _American Economic Journal: Applied Economics, 9(4)_, 216-49.
#
# The original paper, data and code can be accessed [here](https://www.aeaweb.org/articles?id=10.1257/app.20160267).
#
# ##### Information about replication and individual contributions:
#
# * All figures and tables, except for Figure 7, have been replicated and are numbered as they appear in Angrist et al. (2017).
# * Figures 4 to 6 have been modified and extended as detailed below.
# * Figures that constitute an original contribution and extension to the original paper are numbered using the prefix **E**.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction-1">1. Introduction</a></span></li><li><span><a href="#2.-Theoretical-Background" data-toc-modified-id="2.-Theoretical-Background-2">2. Theoretical Background</a></span></li><li><span><a href="#3.-Identification" data-toc-modified-id="3.-Identification-3">3. Identification</a></span></li><li><span><a href="#4.-Empirical-Strategy" data-toc-modified-id="4.-Empirical-Strategy-4">4. Empirical Strategy</a></span></li><li><span><a href="#5.-Replication-of-Lindo-et-al.-(2010)" data-toc-modified-id="5.-Replication-of-Lindo-et-al.-(2010)-5">5. Replication of Lindo et al. (2010)</a></span><ul class="toc-item"><li><span><a href="#5.1.-Data-&amp;-Descriptive-Statistics" data-toc-modified-id="5.1.-Data-&amp;-Descriptive-Statistics-5.1">5.1. Data &amp; Descriptive Statistics</a></span></li><li><span><a href="#5.2.-Results" data-toc-modified-id="5.2.-Results-5.2">5.2. Results</a></span><ul class="toc-item"><li><span><a href="#5.2.1.-Tests-of-the-Validity-of-the-RD-Approach" data-toc-modified-id="5.2.1.-Tests-of-the-Validity-of-the-RD-Approach-5.2.1">5.2.1. Tests of the Validity of the RD Approach</a></span></li><li><span><a href="#i.--Extension:-Visual-Validity-Check" data-toc-modified-id="i.--Extension:-Visual-Validity-Check-5.2.2">i.  Extension: Visual Validity Check</a></span></li><li><span><a href="#ii.-Advanced-Validity-Check" data-toc-modified-id="ii.-Advanced-Validity-Check-5.2.3">ii. Advanced Validity Check</a></span></li><li><span><a href="#5.2.2.-First-Year-GPAs-and-Academic-Probation" data-toc-modified-id="5.2.2.-First-Year-GPAs-and-Academic-Probation-5.2.4">5.2.2. First Year GPAs and Academic Probation</a></span></li><li><span><a href="#5.2.3.-The-Immediate-Response-to-Academic-Probation" data-toc-modified-id="5.2.3.-The-Immediate-Response-to-Academic-Probation-5.2.5">5.2.3. The Immediate Response to Academic Probation</a></span></li><li><span><a href="#5.2.4.-The-Impact-onSubsequent-Performance" data-toc-modified-id="5.2.4.-The-Impact-onSubsequent-Performance-5.2.6">5.2.4. The Impact onSubsequent Performance</a></span></li><li><span><a href="#i.-Main-Results-for-Impact-on-GPA-&amp;-Probability-of-Placing-Above-Cutoff-in-the-Next-Term" data-toc-modified-id="i.-Main-Results-for-Impact-on-GPA-&amp;-Probability-of-Placing-Above-Cutoff-in-the-Next-Term-5.2.7">i. Main Results for Impact on GPA &amp; Probability of Placing Above Cutoff in the Next Term</a></span></li><li><span><a href="#ii.-Formal-Bound-Analysis-on-Subsequent-GPA-(partial-extension)" data-toc-modified-id="ii.-Formal-Bound-Analysis-on-Subsequent-GPA-(partial-extension)-5.2.8">ii. Formal Bound Analysis on Subsequent GPA (partial extension)</a></span></li><li><span><a href="#5.2.5.-The-Impacts-on-Graduation" data-toc-modified-id="5.2.5.-The-Impacts-on-Graduation-5.2.9">5.2.5. The Impacts on Graduation</a></span></li></ul></li></ul></li><li><span><a href="#6.-Extension:-Robustness-Checks" data-toc-modified-id="6.-Extension:-Robustness-Checks-6">6. Extension: Robustness Checks</a></span><ul class="toc-item"><li><span><a href="#6.1.--A-Closer-Look-at-Students'-Subsequent-Performance." data-toc-modified-id="6.1.--A-Closer-Look-at-Students'-Subsequent-Performance.-6.1">6.1.  A Closer Look at Students' Subsequent Performance.</a></span><ul class="toc-item"><li><span><a href="#6.1.1.-Subsequent-Performance-and-Total-Credits-in-Year-2" data-toc-modified-id="6.1.1.-Subsequent-Performance-and-Total-Credits-in-Year-2-6.1.1">6.1.1. Subsequent Performance and Total Credits in Year 2</a></span></li><li><span><a href="#6.1.2.-Subsequent-Cumulative-Grade-Point-Average-(CGPA)" data-toc-modified-id="6.1.2.-Subsequent-Cumulative-Grade-Point-Average-(CGPA)-6.1.2">6.1.2. Subsequent Cumulative Grade Point Average (CGPA)</a></span></li></ul></li><li><span><a href="#6.2.-Bandwidth-Sensitivity" data-toc-modified-id="6.2.-Bandwidth-Sensitivity-6.2">6.2. Bandwidth Sensitivity</a></span></li></ul></li><li><span><a href="#7.-Conclusion" data-toc-modified-id="7.-Conclusion-7">7. Conclusion</a></span></li><li><span><a href="#8.-References" data-toc-modified-id="8.-References-8">8. References</a></span></li></ul></div>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels as sm
import statsmodels.formula.api as smf
import statsmodels.api as sm_api
import matplotlib.pyplot as plt
from linearmodels import IV2SLS
from IPython.display import HTML

# %%
from auxiliary.auxiliary_plots import *
from auxiliary.auxiliary_tables import *
from auxiliary.auxiliary_regressions import *

# %% [markdown]
# ---
# # 1. Introduction
# ---

# %% [markdown]
# The relationship between class size and student achievement has long been at the center of public and academic discussions on educational policy. The notion that reducing class size has sizable positive effects on student achievement is a widely held belief among families, teachers, and educationalists. Numerous mechanisms have been proposed for this supposed causal relationship. Teachers may prepare both the whole class and individual students more effectively as time spent on class management decreases, time devoted to individual pupils increases and it is easier to tailor teaching methods to a particular class; teacher and student performance may benefit from higher morale; pupils, especially those with a weak socio-economic background, may identify more strongly with the educational process (Averett and McLennan, 2004). Policymakers have at times embraced this view and implemented class-size reduction (CSR) programs. In the US, California passed a CSR reform aimed at kindergarteners in 1996, while Florida enshrined new class size caps in the state constitution in 2002.
#
# Social scientists have devoted their attention to the topic as well, attempting to quantify potential gains from smaller classes. In fact, given the hefty price tag attached to CSR programs ([Florida's program reportedly cost USD 46 billion over a 17-year horizon](http://www.fldoe.org/finance/budget/class-size/)), the magnitude of their returns is of crucial interest. Krueger's (1999) prominent analysis of the STAR project, a randomized experiment conducted in Tennessee from 1985 to 1989, concluded that K-3 pupils attending one-third smaller classes (7 to 8 fewer students) received a boost in their test scores of 0.19 to 0.28 standard deviations. A study of project STAR's long-term effects suggested that treated individuals were 2 percentage points more likely to enroll in college (Chetty et al., 2011). Angrist and Lavy (1999) found similarly substantial class-size effects for 4th and 5th graders in Israel, where classes are capped at 40 students, but these findings were called into question by Angrist and Lavy (2019), who estimated robust zero class-size effects using more recent data. CSR initiatives in Connecticut, Florida, and California were also shown to exhibit either no (Hoxby, 2000; Chingos, 2012) or small returns (Jepsen and Rivkin, 2009). In sum, the evidence provides some support to the view that smaller classes enhance student performance, although the benefits appear to be small and concentrated at an early stage of education.
#
# Angrist, Battistin, and Vuri (2017) add to the literature by investigating the implications of test score manipulation for the CSR research using data on INVALSI tests, yearly standardized tests covering mathematics and Italian language skills and administered to certain grades of all Italian schools. Based on Angrist and Lavy (1999), the authors first employ a **parametric fuzzy regression discontinuity (RD) design** that exploits mandatory class-size caps to estimate the effect of smaller classes on student achievement for second and fifth-graders, then examine the role of score manipulation in explaining the substantial gap in estimates of class-size effects between Southern Italy and the rest of the country. In fact, it appears that teachers in the South have engaged to a greater extent in shirking when correcting and transcribing the results of the paper-based tests. The final model, which is augmented with an **instrumental variable** for score manipulation, finds that class-size effects vanish. The main contribution of this paper lies in illustrating how in certain test settings smaller classes can incentivize test score manipulation and thereby drive estimates of class-size effects.

# %% [markdown]
# ---
# # 2. Identification Strategy
# ---

# %% [markdown]
# Researchers attempting to capture the causal effect of class size (the treatment variable) on student achievement (the outcome variable) are confronted with well-known issues of identification. Given that treatment is not randomly assigned, pupils attending smaller classes can be expected to differ in meaningful ways, e.g. socio-economic conditions, from those attending larger ones, although it is not readily apparent whether the **selection bias** should be expected to be positive or negative. For example, if educational investment in one's child is a positive function of income, better-off families may actively seek out schools with smaller classes and wealthier communities may invest in and/or lobby for CSR interventions. At the same time, smaller classes may be more frequent in the less densely populated rural areas, which tend to be poorer. Furthermore, it cannot be assumed that the factors determining selection are all observed by the researcher, meaning that it does not suffice to condition on the observable characteristics of the students.
#
# The graph below summarizes the causal relationships that are at play in the Italian setting as laid out in Angrist et al. (2017). Test scores (the outcome variable $Y$) are affected by class size (the treatment variable of interest $D_1$) and observables $W$ like parental education or immigrant status, but also by unobservables $U_1$, e.g. innate ability, neighborhood or school management. While both $W$ and $U_1$ may have a causal effect on selection into treatment $D_1$ *and* the outcome $Y$, only the backdoor path $D_1 \leftarrow W \rightarrow Y$ can be blocked since it is impossible to condition on unobservables. Fortunately, agents have imperfect control over the treatment variable $D_1$. In fact, while families apply to the school of their choice in February, the composition of classes is unknown until shortly before the school start in September, at which point reassignments are difficult and need to be authorized. In addition, funding and most organizational aspects, especially when it comes to primary education, depend on the central government. Therefore, treatment is not at the full discretion of the school staff either. The nation-wide class-size minima and maxima result in what Angrist and Lavy called **Maimonides' Rule**, which predicts class size to be a nonlinear and discontinuous function of grade enrollment (see Figures 2 and 3 below). This provides a credible source of exogenous variation needed to deal with the selection bias and the nonlinear nature of the function allows to apply the fuzzy RD design. As shown in the graph, $D_1$ can be instrumented by the class size predicted by Maimonides' Rule $Z_1$, which in turn is a function of grade enrollment (the running variable $X$). Note that $Z_1$ is assumed to be a conditional IV, meaning that the running variable $X$ might affect the outcome $Y$ and needs to be conditioned on.
#
# However, Angrist et al. uncover another problematic causal nexus as test score manipulation by teachers (the second treatment variable $D_2$) alters average test scores $Y$ in a non-random fashion. First, class size $D_1$ has a negative effect on $D_2$ because in larger classes it is more likely that tests are corrected and the results are transcribed by more than one teacher. Second, it appears that the phenomenon of manipulation is more widespread in the South than in the rest of the country. $D_1$ being a collider variable and $D_2$ and $Y$ being potentially driven by common causes that are unobservable, another source of exogenous variation is needed to identify the effect of $D_2$ on $Y$. Since **monitors** are shown to deter manipulation and are **randomly assigned** by the INVALSI institute, their presence at the institution $Z_2$ can be used as an instrument for $D_2$.

# %% [markdown]
# #### Figure E1: Causal Graph
# ![ERROR: Here causal_graph should be displayed](files/causal_graph.JPG)
#
# *Click [here](https://github.com/HumanCapitalAnalysis/microeconometrics-course-project-FedericoAlexanderRizzuto/blob/master/files/causal_graph.JPG) if the image is not rendered.*

# %% [markdown]
# In short, Maimonides' Rule $Z_1$ represents a valid instrumental variable because it arguably affects the outcome variable $Y$ only through $D_1$ once the back-door path $Z_1 \leftarrow X \rightarrow Y$ is closed by conditioning on grade enrollment $X$; monitoring is a valid IV because random assignment guarantees it to cause $Y$ only via $D_2$. By simultaneously instrumenting $D_1$ and $D_2$ while conditioning on $W$ and $X$, the effect of class size on test scores is finally identified.

# %% [markdown]
# ---
# # 3. Empirical Strategy
# ---

# %% [markdown]
# The starting point for implementing the identification strategy outlined above is the following equation:
#
# $\qquad (2) \qquad \qquad y_{igkt} = \rho_0(t,g) + \beta s_{igkt} + \rho_1 r_{gkt} + \rho_2 r^2_{gkt} + \epsilon_{igkt} $
#
# where $y_{igkt}$, the standardized math or Italian language test score for class $i$ in grade $g$ at school $k$ in year $t$, is estimated as a second-order polynomial function of year and grade controls $\rho_0(t,g)$, class size divided by ten $s_{igkt}$ and grade enrollment $r_{gkt}$. The quadratic running variable allows to exploit the nonlinearity of the Maimonides' Rule:
#
# $\qquad (1) \qquad \qquad f_{igkt} = \frac{r_{gkt}}{int(r_{gkt}-1)/c_{gt}+1} $
#
# where $f_{igkt}$, the predicted size of class $i$, is a function of grade enrollment and of the relevant maximum number of students per class $c_{gt}$ (25 or 27, respectively for classes unaffected and affected by the 2009 reform). In fact, after a benchmark OLS estimation of equation $\text{(2)}$, $s_{igkt}$ is instrumented by $f_{igkt}$. The following table summarizes the set of controls $\rho_0(t,g)$:
#
# |                      **Observables**                                  ||
# |------------------------------------|-----------------------------------|
# | Female                             | Nonresponses - Female             |
# | Immigrant                          | Nonresponses - Immigrant          |
# | Father high school dropout         | Father high school graduate       |
# | Father college graduate            | Mother employed                   |
# | Mother homemaker                   | Mother unemployed                 |
# | Nonresponses - Mothers' education  | Region dummy                      |
# | Year dummy                         | Grade dummy                       |
# | Reform dummy                       | Region-enrollment interaction term|
#
#
# To partially account for misreporting, item nonresponses (the percentage of students in a class for which data is missing) are included as observables. The nonresponse variables on fathers' education and mothers' occupation were dropped due to collinearity issues. The reform dummy reflects whether the class was subject to $c_{gt}$ equal to 25 or 27. It should be noted that the data related to the demographic and socio-economic background of pupils are reported by the school staff, while the other controls are administrative in nature or collected by the INVALSI institute. This distinction will be relevant when discussing misreporting. As the relationship of grade enrollment with the endogenous and the outcome variables is influenced by geographical factors (see Figures 4 to 6), equation $(2)$ is then augmented by adding the polynomial interaction between the running variable and the region dummy and other terms that allow the quadratic function to change over enrollment windows (the "interacted" model). Table 2 reports the 2SLS estimates for this model in addition to the OLS and 2SLS estimates of equation $(2)$.
#
# Motivated by the finding of particularly high class-size effects in the South, Angrist et al. include a second endogenous variable in the model, namely the cheating dummy $m_{igtk}$. Using a second larger dataset (the unit of observation is the student), the authors have constructed a dummy that flags classes with abnormally high scores, low variance, and suspicious patterns, i.e. classes where teachers likely have manipulated the outcome variable. As discussed above, this second treatment variable is instrumented by the presence of monitors at the institution $M_{igkt}$. Thus, equation $(2)$ becomes:
#
# $\qquad (4) \qquad \qquad y_{igkt} = \rho_0(t,g) + \beta_1 s_{igkt} + \beta_2 m_{igtk} + \rho_1 r_{gkt} + \rho_2 r^2_{gkt} + \eta_{igkt} $
#
# with the first-stage regressions being:
#
# $\qquad (5) \qquad \qquad s_{igkt} = \lambda_{10}(t,g) + \mu_{11} f_{igkt} + \mu_{12} M_{igtk} + \lambda_{11} r_{gkt} + \lambda_{12} r^2_{gkt} + \xi_{ik} $
#
# $\qquad (6) \qquad \qquad m_{igkt} = \lambda_{20}(t,g) + \mu_{21} f_{igkt} + \mu_{22} M_{igtk} + \lambda_{21} r_{gkt} + \lambda_{22} r^2_{gkt} + v_{ik} $
#
# Estimates for equation $(4)$ are found in Table 8, while those for the first stage are presented in Table 7. The table below summarizes the key elements of the final model. The causal effect of the endogenous variables $s_{igkt}$ and $m_{igkt}$ on math and language scores $y_{igkt}$ is recovered by instrumenting them by the presence of monitors $M_{igtk}$ and the predicted class size $f_{igkt}$, which is a function of the running variable $r_{gkt}$.
#
#
# | **Main Outcome**       | **Treatments**               | **Instruments**                        | **Assignment Variable**             |
# |------------------------|------------------------------|----------------------------------------|-------------------------------------|
# | Test scores $y_{igkt}$ | Class size $s_{igkt}$        | Maimonides rule $f_{igkt}$             | Grade enrollment at school $r_{gkt}$|
# | .                      | Score manipulation $m_{igkt}$| Monitors at the institution $M_{igtk}$ | .                                   |

# %% [markdown]
# ---
# # 4. Replication of Angrist et al. (2017)
# ---

# %% [markdown]
# ## 4.1. Data & Descriptive Statistics

# %%
# load dataset and create the North-Center dummy
df = pd.read_stata(r'data/smallmo.dta')
df = prepare_data(df)
print('The dataset includes', len(df), 'observations.','There are',df.isnull().any(axis = 1).sum(),'missing observations:',
      'The cheating dummies for Italian language and math test scores have',df['our_CHEAT_ital'].isna().sum(),
      'and',df['our_CHEAT_math'].isna().sum(),'NaNs, respectively.')
# Out:
# The dataset includes 140010 observations. There are 21 missing observations: The cheating dummies for Italian language and math test scores have 7 and 14 NaNs, respectively.

# %% [markdown]
# Angrist et al. (2017) use repeated cross-sectional data on Italian language and mathematics test scores of second and fifth-graders for the years 2009-10 to 2011-12. They subsample the data collected by the INVALSI institute to exclude classes below the mandatory minimum number of pupils (10 before 2010 and 15 from 2011), instances concerning remote areas in the mountains or on islands, as well as schools with grade enrollment above 160, i.e. where the Maimonides' Rule ceases to meaningfully predict actual class size. With the unit of observation being the class, the final dataset counts 140010 observations, about 70000 for each grade. The North has the most classes (around 10000 per grade per year), followed by the South (between 8000 and 9000 per grade per year) and the Center (about 4000 per grade per year). The number of second-grade classes tends to decrease over the three years, due to the reform discussed below, while there is no clear trend for the fifth grade.

# %% [markdown]
# #### Figure E2: Number of Observations by Area, Grade and Survey Year

# %%
plot_count_classes(df)

# %% [markdown]
# For the remainder of the analysis, North and Center are grouped together. While culturally and historically Italy has divided into North, Center, and South, to the purpose of this analysis it is the divide in economic performance and institutional quality between the South (Sicily and Sardinia included) and the rest of the country that is of interest. As discussed above, differences in socio-economic conditions are relevant when addressing selection into treatment $D_1$, those in the outcome variable $Y$ turn out to be symptomatic of score manipulation being more common in the South.
#
# As can be seen in Figure E3, classes in the North and Center are more likely to have higher shares of pupils with immigrant status or employed mothers than in the South. Figure E4 illustrates how the divide transpires from the distribution of average test scores as well, with dispersion being higher and exceptionally good grades being much more frequent in the South. These anomalies concern math more than language scores, and second-grade more than fifth-grade classes. This also becomes apparent when looking at the trend from the second to the fifth grade. Language test scores display the same tendency in the whole country: the distribution shifts to the right, with a higher mean and lower variance. In contrast, student performance in math improves on average in the North and in the Center, while worsening in the South due to markedly fewer observations in the high-end and more observations in the low-end spectrum. The random monitoring experiment later reveals how these differences in the test score distribution are in fact the result of test score manipulation (see Figure E6 for a visualization of the monitoring effect).

# %% [markdown]
# #### Figure E3: Distribution of Demographic Variables by Grade and Area

# %%
# the x axis is set to start at 0.1 to exclude the spike of observations around zero
# for transparency, the function allows to change the limits of the axes
# to zoom out set the second argument to [0,1], the third to [0,60]
plot_demo_dist(df,xlim=[0.1,1], ylim=[0,5])

# %% [markdown]
# #### Figure E4: Distribution of Math and Italian Language Test Scores by Grade and Area

# %%
plot_score_dist(df)

# %% [markdown]
# Panels A, B, and C of Table 1 report descriptive statistics respectively for the class, school, and institution level (schools are oftentimes grouped together and managed as one unit). Panel A confirms what emerged from the graphical analysis:
# * The share of immigrant students is 9 p.p. higher in the North/Center than in the South;
# * There is a wide regional gap of about 30 p.p. in employment rates of pupils' mothers, although this value appears to be somewhat inflated (see Table 4 and Figure E5). In contrast, the percentage of fathers who graduated from high school does not show such stark discrepancies;
# * Classes typically consist of 20 students;
# * Mean test scores tend to differ by less than 2 p.p. between the North/Center and the South, except for math in the second grade (6.5 p.p.), and are about 6 to 10 p.p. higher in Italian language than in math;
# * Test scores in the South consistently display a higher standard deviation.
#
# Panel A also reports the proportion of classes with compromised scores, which for the South is 9 p.p. and 12 p.p. higher, respectively for language and math tests, than for the rest of Italy.
#
# Finally, according to Panel C, monitors have visited 23% of institutions in the North and Center, and 20% of institutions in the South.

# %% [markdown]
# ---
# <span style="color:orange"> __NOTE__</span> Some statistics displayed in Table 1 diverge from those reported in the original paper but align with the output of the original Stata code. I have contacted the authors, who have looked into it and confirmed that some numbers had been swapped.
# In particular, the standard deviations and/or the means of the following variables appear to be incorrect: *Female, Immigrant, Father HS, Mother employed, Pct correct: Math, External monitor*. The rest of the analysis is unaffected by this problem.
#
# ---

# %% [markdown]
# #### Table 1 - Descriptive Statistics

# %% [markdown]
# _Panel A. Class characteristics: Means and standard deviations (in parentheses) are computed using one observation per class._
#
# _*Conditional on non-missing survey responses_

# %%
create_table1a(df)
# Out:
# grade                                Grade 2                          Grade 5  \
# north_center                           Italy North/Center     South     Italy
# Female*                      mean       0.49         0.49      0.49      0.49
#                              std        0.11         0.11      0.11      0.11
# Immigrant*                   mean       0.10         0.14      0.03      0.10
#                              std        0.12         0.13      0.06      0.12
# Father HS*                   mean       0.34         0.34      0.33      0.31
#                              std        0.14         0.13      0.16      0.15
# Mother employed*             mean       0.54         0.67      0.37      0.53
#                              std        0.23         0.16      0.20      0.23
# Pct correct: Math            mean      63.91        61.54     68.02     64.16
#                              std       13.15        10.29     16.20     12.91
# Pct correct: Language        mean      69.78        69.18     70.81     74.22
#                              std       10.92         9.18     13.34      8.90
# Class size                   mean      20.12        20.25     19.90     19.66
#                              std        3.40         3.35      3.48      3.72
# Score manipulation: Math     mean       0.06         0.02      0.14      0.07
#                              std        0.24         0.13      0.35      0.25
# Score manipulation: Language mean       0.05         0.02      0.11      0.06
#                              std        0.23         0.15      0.31      0.23
# Number of classes            count  67453.00     42747.00  24706.00  72536.00
#
# grade
# north_center                       North/Center     South
# Female*                      mean          0.49      0.49
#                              std           0.11      0.11
# Immigrant*                   mean          0.14      0.03
#                              std           0.13      0.06
# Father HS*                   mean          0.32      0.30
#                              std           0.14      0.16
# Mother employed*             mean          0.65      0.36
#                              std           0.16      0.19
# Pct correct: Math            mean         63.26     65.61
#                              std          10.87     15.53
# Pct correct: Language        mean         74.27     74.12
#                              std           7.47     10.82
# Class size                   mean         19.90     19.28
#                              std           3.67      3.76
# Score manipulation: Math     mean          0.02      0.14
#                              std           0.15      0.34
# Score manipulation: Language mean          0.02      0.11
#                              std           0.15      0.31
# Number of classes            count     44739.00  27797.00

# %% [markdown]
# _Panel B. School characteristics: Means and standard deviations (in parentheses) are computed using one observation per school._

# %%
create_table1b(df)
# Out:
# grade                     Grade 2                          Grade 5  \
# north_center                Italy North/Center     South     Italy
# Number of classes mean       1.95         1.87      2.11      1.94
#                   std        1.11         1.01      1.27      1.10
# Enrollment        mean      40.52        38.83     43.83     38.87
#                   std       25.16        22.99     28.64     25.19
# Number of schools count  34591.00     22863.00  11728.00  37476.00
#
# grade
# north_center            North/Center     South
# Number of classes mean          1.85      2.10
#                   std           0.98      1.28
# Enrollment        mean         37.32     41.69
#                   std          22.76     28.91
# Number of schools count     24225.00  13251.00

# %% [markdown]
# _Panel C. Institution characteristics: Means and standard deviations (in parentheses) are computed using one observation per institution._

# %%
create_table1c(df)
# Out:
# grade                     Grade 2                         Grade 5  \
# north_center                Italy North/Center    South     Italy
# Number of classes mean       3.89         4.33     3.31      4.07
#                   std        1.97         1.95     1.85      1.95
# Enrollment        mean      86.00        95.33    73.68     85.17
#                   std       40.61        39.52    38.71     40.45
# External monitor  mean       0.22         0.23     0.20      0.21
#                   std        0.41         0.42     0.40      0.41
# Number of schools count  17333.00      9866.00  7467.00  17830.00
#
# grade
# north_center            North/Center    South
# Number of classes mean          4.48     3.55
#                   std           1.91     1.88
# Enrollment        mean         94.02    73.88
#                   std          39.11    39.31
# External monitor  mean          0.23     0.20
#                   std           0.42     0.40
# Number of schools count      9997.00  7833.00

# %%
print('There are', len(df[df['d']=='Grade 2 from 2010']), 'observations affected by the 2009 reform.')
# Out:
# There are 43545 observations affected by the 2009 reform.

# %% [markdown]
# Class size in Italy was mandated to range from 10 to 25 students until a 2009 reform (*Decreto del President della Repubblica 81/2009*), and from 15 to 27 thereafter. Given their stagged rollout, these changes interested only second-graders in the years 2010-11 and 2011-12, i.e. 43545 classes in the sample. Schools were allowed to diverge from these rules by 10 percent at the class-size cap and under special circumstances, e.g. remote location of the school or the presence of a student with disabilities. Figures 2 and 3 plot school enrollment against actual and predicted class size averages, respectively for classes unaffected and affected by the reform. It appears that Maimonides' Rule manages to follow actual class size relatively well up to an enrollment of 75 students, with deviations at the class-size cap typically consisting in adding a class earlier than mandated. The fit is worse for classes affected by the 2009 reform.

# %% [markdown]
# #### Figure 2 - Maimonides in Italy (Pre-Reform)

# %%
create_fig2(df)

# %% [markdown]
# #### Figure 3 - Maimonides in Italy (Post-Reform)

# %%
create_fig3(df)

# %% [markdown]
# ## 4.2. Graphical RD analysis

# %% [markdown]
# To better capture the relationship of the running variable with the outcome and the two endogenous variables, Angrist et al. proceed with a graphical RD analysis. Focusing on a subsample of classes that are at most 12 students away from either side of each cutoff (multiples of $c_{gt}$), they plot the residuals from regressing class size (Figure 4), test scores (Figure 5) and score manipulation (Figure 6) on the set of controls specified in Section 3, minus the assignment variable. In light of the tolerance level of 10% deviation from the Maimonides' Rule at cutoffs granted to the schools, smoothing lines exclude residuals in a [-2,+2] window.
#
# Figure 4 gives visual confirmation of the fact that the variance in class size is explained by the running variable and not by observables. In line with expectations, smoothed residuals show a clear drop of about 2 to 4 pupils _near_ the cutoff, raw residuals less so because of the aforementioned flexibility _at_ the cutoff, as confirmed by the fact that class size peaks and decreases before the cutoff. Note that Maimonides' Rule is enforced less strictly in the South than in the North/Center.

# %% [markdown]
# ---
# <span style="color:orange">**NOTE**</span> Figures 4 to 6 have been modified. In contrast to Angrist et al. (2017), where only smoothed residuals are shown, here residuals are plotted against grade enrollment first as raw averages (the scatter plot) and then smoothed by a one-sided three-point moving average that leaves out observations in the [-2;+2] window (the line graph). The objective was to guarantee transparency (the one-sided three-point average already imposes structure on the data) and to adhere more closely to the standard implementation of RD graphical analysis. Further, Figures 5 and 6 have been amended to display residuals by region *and* grade for consistency with Figure 4; their y axes have been adapted as well to accomodate the change in levels.
#
# ---

# %% [markdown]
# #### Figure 4 - RD Graphical Analysis: Class Size Residuals as a Function of Enrollment

# %%
create_fig4(df)

# %% [markdown]
# Figure 5 plots the residuals from regressing test scores on the controls. The picture that emerges is not as clear-cut as in Figure 4 or, given that the raw averages are shown and the graph is disaggregated by grade, as in Angrist et al. (2017). However, it is readily apparent that the share of unexplained variance in test scores is higher for math and for the South, implying that the anomalies in the distribution of test scores observed in Figure E4 cannot be explained by observables. As to the relation with the running variable, the evidence is mixed. For the South, crossing the cutoff appears to be associated with a jump in test scores of about $0.02 \sigma$, except for fifth-grade Italian language tests. In the North and Center, this is the case only for math scores in the second grade, with residuals otherwise appearing to be unrelated to enrollment and if anything showing a tendency to decrease to the right of the cutoff.

# %% [markdown]
# #### Figure 5 - RD Graphical Analysis: Test Score Residuals as a Function of Enrollment

# %%
create_fig5a(df)

# %%
create_fig5b(df)

# %% [markdown]
# Finally, Figures 6 depicts if and how the share of classes with compromised scores changes with enrollment, once the influence of observables has been accounted for. In the North and Center, manipulation appears to be largely unrelated to the assignment variable, while in the South it increases when the cutoff is crossed. This finding will be confirmed by the regressions summarized in Table 3.

# %% [markdown]
# #### Figure 6 - RD Graphical Analysis: Manipulation Residuals as a Function of Enrollment

# %%
create_fig6a(df)

# %%
create_fig6b(df)

# %% [markdown]
# In sum, the graphical analysis confirms the appropriateness of using grade enrollment and Maimonides' Rule respectively as the running variable and the instrument in a parametric fuzzy RD framework, given the nonlinear and discontinuous relation between class size and enrollment. In addition, it highlights the need to find a source of exogenous variation for manipulation, an endogenous treatment with patterns that vary across regions and are likely to be influenced by non-observables.

# %% [markdown]
# ## 4.3. Maimonides-IV Estimates

# %% [markdown]
# In this section, the first part of the empirical strategy outlined in Section 3 is implemented, i.e. the Maimonides-IV estimation.
#
# Table 2 reports the class-size estimates obtained from running equation $(2)$, detailing how the assignment variable enters it: in columns 7 to 9, interaction terms of enrollment with the region dummy and with the deviation from cutoffs are added to equation. For the simple OLS specification, which does not properly address the selection bias, estimates of the class-size effect diverge in direction: they are negative for the North/Center, i.e. additional ten students per class are associated with worse performance, but positive, although statistically insignificant in math, for Southern Italy. The situation reverses once the Maimonides-IV is used, with the class-size effect of the South becoming negative and twice to three times larger than that of the rest of the country. In particular, adding ten students to the average class decreases math test scores by $0.042\sigma$ and $0.129\sigma$, respectively in the North/Center and in the South, in the interacted model. Note that only for language scores in the North/Center the estimate given by the last specification is statistically insignificant.
#
# ---
# <span style="color:orange">**NOTE**</span> Standard errors shown in this and in all subsequent tables are robust and clustered on school and grade.
#
# ---

# %% [markdown]
# #### Table 2 - The Effect of Class Size on Test Scores (OLS vs 2SLS)

# %%
create_table2and3(df,['answers_math_std','answers_ital_std'],['Panel A. Math', 'Panel B. Language'])
# Out:
#                                                OLS                      \
#                                              Italy North/Center  South
# Panel A. Math     Class size - coefficient  -0.008       -0.022  0.009
#                   Class size - SE            0.007        0.007  0.015
#                   Enrollment                     X            X      X
#                   Enrollment squared             X            X      X
#                   Interactions
#                   Observations              140010        87498  52512
# Panel B. Language Class size - coefficient   0.003       -0.019  0.033
#                   Class size - SE            0.006        0.005  0.011
#                   Enrollment                     X            X      X
#                   Enrollment squared             X            X      X
#                   Interactions
#                   Observations              140010        87498  52512
#
#                                            IV/2SLS                       \
#                                              Italy North/Center   South
# Panel A. Math     Class size - coefficient  -0.052       -0.044  -0.096
#                   Class size - SE            0.013        0.012   0.036
#                   Enrollment                     X            X       X
#                   Enrollment squared             X            X       X
#                   Interactions
#                   Observations              140010        87498   52512
# Panel B. Language Class size - coefficient  -0.040       -0.031  -0.064
#                   Class size - SE            0.011        0.009   0.029
#                   Enrollment                     X            X       X
#                   Enrollment squared             X            X       X
#                   Interactions
#                   Observations              140010        87498   52512
#
#                                             IV/2SLS
#                                               Italy North/Center   South
# Panel A. Math     Class size - coefficient   -0.061       -0.042  -0.129
#                   Class size - SE             0.020        0.017   0.051
#                   Enrollment                      X            X       X
#                   Enrollment squared              X            X       X
#                   Interactions                    X            X       X
#                   Observations               140010        87498   52512
# Panel B. Language Class size - coefficient   -0.041       -0.021  -0.094
#                   Class size - SE             0.016        0.014   0.040
#                   Enrollment                      X            X       X
#                   Enrollment squared              X            X       X
#                   Interactions                    X            X       X
#                   Observations               140010        87498   52512

# %% [markdown]
# Table 3 presents the estimated effect of class size on manipulation by reiterating the regressions from Table 2 with the dummy for compromised scores in place of test scores. Even if in line with Figure 6 the estimates are not statistically significant for Northern and Central Italy, it suggests that larger classes do indeed tend to deter manipulation. In particular, 2SLS predicts that ten additional students decrease manipulation by 4 to 6 p.p. in Southern Italy.

# %% [markdown]
# #### Table 3 - The Effect of Class Size on Manipulation (OLS vs 2SLS)

# %%
create_table2and3(df,['our_CHEAT_math','our_CHEAT_ital'],['Panel A. Math', 'Panel B. Language'])
# Out:
#                                                OLS                       \
#                                              Italy North/Center   South
# Panel A. Math     Class size - coefficient  -0.016       -0.007  -0.031
#                   Class size - SE            0.002        0.002   0.006
#                   Enrollment                     X            X       X
#                   Enrollment squared             X            X       X
#                   Interactions
#                   Observations              139996        87491   52505
# Panel B. Language Class size - coefficient  -0.017       -0.012  -0.024
#                   Class size - SE            0.002        0.002   0.005
#                   Enrollment                     X            X       X
#                   Enrollment squared             X            X       X
#                   Interactions
#                   Observations              140003        87493   52510
#
#                                            IV/2SLS                       \
#                                              Italy North/Center   South
# Panel A. Math     Class size - coefficient  -0.019       -0.004  -0.054
#                   Class size - SE            0.005        0.003   0.014
#                   Enrollment                     X            X       X
#                   Enrollment squared             X            X       X
#                   Interactions
#                   Observations              139996        87491   52505
# Panel B. Language Class size - coefficient  -0.020       -0.012  -0.040
#                   Class size - SE            0.004        0.003   0.013
#                   Enrollment                     X            X       X
#                   Enrollment squared             X            X       X
#                   Interactions
#                   Observations              140003        87493   52510
#
#                                             IV/2SLS
#                                               Italy North/Center   South
# Panel A. Math     Class size - coefficient   -0.018       -0.005  -0.047
#                   Class size - SE             0.007        0.004   0.020
#                   Enrollment                      X            X       X
#                   Enrollment squared              X            X       X
#                   Interactions                    X            X       X
#                   Observations               139996        87491   52505
# Panel B. Language Class size - coefficient   -0.016       -0.006  -0.038
#                   Class size - SE             0.006        0.005   0.018
#                   Enrollment                      X            X       X
#                   Enrollment squared              X            X       X
#                   Interactions                    X            X       X
#                   Observations               140003        87493   52510

# %% [markdown]
# ## 4.4. Monitors as Instrument for Manipulation

# %% [markdown]
# The causal effect of class size on score manipulation constitutes a clear threat to the validity of the Maimonides-IV estimation. As discussed in Section 2, the back-door path $D_1 \rightarrow D_2 \rightarrow Y$ cannot be closed by conditioning on score manipulation $D_2$ because it cannot be assumed that $Y$ and $D_2$ are not driven by common unobservables. The identification strategy thus relies on monitoring to introduce exogenous variation. Since the assignment of monitors by the INVALSI institute is not perfectly random, this section makes sure that the covariates are well balanced across treatment and control group, then analyses the monitoring effect on test scores and on their manipulation.
#
# Figure 4 compares the means of a set of covariates between institutions with and without a monitor. In addition, it shows the coefficients and standard deviations of the monitoring dummy from regressing each covariate on the monitoring, grade, and year dummies, and on the interaction term between enrollment and region. In other words, it shows the difference in control and treatment means due to the presence of monitors while accounting for fixed effects. Unlike administrative variables, demographic ones appear to be imbalanced. In particular, monitoring increases the reported share of immigrant students, especially in Southern Italy, of students with a father who graduated from high school, and of students with an employed mother. More importantly, the presence of monitors decrease nonresponses by about 1 p.p. in the North/Center to 3 p.p. in the South (the only insignificant nonresponse indicator is that on mothers' employment status in the North). This, together with the fact that only data reported by the school staff shows imbalances, suggests that these differences in control-treatment means are not due to non-random assignment of monitors but to the higher accuracy in data reporting in presence of monitors.
#
# ---
# <span style="color:orange">**NOTE**</span> Table 4 has been extended to include the treatment means as well, and thus split in two.
#
# ---

# %% [markdown]
# #### Table 4 - Covariate Balance in The Monitoring Experiment

# %%
create_table4a(df)
# Out:
# placeholder                                        Italy            \
# o_math                                        No Monitor   Monitor
# Class size                              mean       19.81     20.11
#                                         std         3.57      3.57
# Grade enrollment at school              mean       53.12     53.82
#                                         std        30.66     30.26
# Percent in class sitting the test       mean        0.94      0.94
#                                         std         0.06      0.06
# Percent in school sitting the test      mean        0.94      0.94
#                                         std         0.05      0.05
# Percent in institution sitting the test mean        0.94      0.94
#                                         std         0.04      0.04
# Female students                         mean        0.48      0.48
#                                         std         0.12      0.12
# Immigrant students                      mean        0.10      0.10
#                                         std         0.12      0.12
# Father HS                               mean        0.25      0.27
#                                         std         0.17      0.17
# Mother employed                         mean        0.44      0.48
#                                         std         0.27      0.26
# Missing data on father's education      mean        0.22      0.20
#                                         std         0.34      0.32
# Missing data on mother's occupation     mean        0.20      0.18
#                                         std         0.33      0.31
# Missing data on country of origin       mean        0.03      0.02
#                                         std         0.16      0.12
# Observations                            count  105685.00  34325.00
#
# placeholder                                   North/Center            \
# o_math                                          No Monitor   Monitor
# Class size                              mean         20.03     20.19
#                                         std           3.51      3.56
# Grade enrollment at school              mean         49.80     49.39
#                                         std          27.56     26.73
# Percent in class sitting the test       mean          0.93      0.94
#                                         std           0.07      0.06
# Percent in school sitting the test      mean          0.93      0.94
#                                         std           0.06      0.05
# Percent in institution sitting the test mean          0.93      0.93
#                                         std           0.04      0.04
# Female students                         mean          0.48      0.48
#                                         std           0.12      0.12
# Immigrant students                      mean          0.14      0.14
#                                         std           0.13      0.13
# Father HS                               mean          0.26      0.27
#                                         std           0.16      0.16
# Mother employed                         mean          0.53      0.55
#                                         std           0.26      0.26
# Missing data on father's education      mean          0.22      0.21
#                                         std           0.34      0.32
# Missing data on mother's occupation     mean          0.20      0.20
#                                         std           0.33      0.32
# Missing data on country of origin       mean          0.03      0.02
#                                         std           0.14      0.11
# Observations                            count     65324.00  22174.00
#
# placeholder                                        South
# o_math                                        No Monitor   Monitor
# Class size                              mean       19.46     19.97
#                                         std         3.65      3.60
# Grade enrollment at school              mean       58.48     61.92
#                                         std        34.44     34.36
# Percent in class sitting the test       mean        0.95      0.95
#                                         std         0.06      0.06
# Percent in school sitting the test      mean        0.95      0.95
#                                         std         0.05      0.05
# Percent in institution sitting the test mean        0.94      0.95
#                                         std         0.05      0.04
# Female students                         mean        0.48      0.48
#                                         std         0.13      0.12
# Immigrant students                      mean        0.03      0.04
#                                         std         0.06      0.06
# Father HS                               mean        0.24      0.26
#                                         std         0.18      0.17
# Mother employed                         mean        0.29      0.35
#                                         std         0.21      0.22
# Missing data on father's education      mean        0.22      0.19
#                                         std         0.34      0.31
# Missing data on mother's occupation     mean        0.19      0.16
#                                         std         0.33      0.30
# Missing data on country of origin       mean        0.05      0.02
#                                         std         0.19      0.14
# Observations                            count   40361.00  12151.00

# %%
create_table4b(df)
# Out:
#                                                       Italy North/Center  \
# Class size - coefficient                             0.0035       0.0018
# Class size - SE                                      0.0030       0.0037
# Grade enrollment at school - coefficient            -0.4011      -0.5477
# Grade enrollment at school - SE                      0.3289       0.3913
# Percent in class sitting the test - coefficient      0.0001       0.0006
# Percent in class sitting the test - SE               0.0005       0.0006
# Percent in school sitting the test - coefficient    -0.0001       0.0005
# Percent in school sitting the test - SE              0.0005       0.0006
# Percent in institution sitting the test - coeff...  -0.0001       0.0005
# Percent in institution sitting the test - SE         0.0004       0.0005
# Female students - coefficient                        0.0012       0.0004
# Female students - SE                                 0.0009       0.0011
# Immigrant students - coefficient                     0.0010       0.0004
# Immigrant students - SE                              0.0010       0.0014
# Father HS - coefficient                              0.0060       0.0061
# Father HS - SE                                       0.0016       0.0019
# Mother employed - coefficient                        0.0085       0.0067
# Mother employed - SE                                 0.0024       0.0031
# Missing data on father's education - coefficient    -0.0217      -0.0186
# Missing data on father's education - SE              0.0034       0.0043
# Missing data on mother's occupation - coefficient   -0.0168      -0.0083
# Missing data on mother's occupation - SE             0.0033       0.0042
# Missing data on country of origin - coefficient     -0.0115      -0.0078
# Missing data on country of origin - SE               0.0013       0.0014
#
#                                                       South
# Class size - coefficient                             0.0062
# Class size - SE                                      0.0051
# Grade enrollment at school - coefficient            -0.1410
# Grade enrollment at school - SE                      0.5909
# Percent in class sitting the test - coefficient     -0.0007
# Percent in class sitting the test - SE               0.0008
# Percent in school sitting the test - coefficient    -0.0010
# Percent in school sitting the test - SE              0.0008
# Percent in institution sitting the test - coeff...  -0.0010
# Percent in institution sitting the test - SE         0.0007
# Female students - coefficient                        0.0027
# Female students - SE                                 0.0016
# Immigrant students - coefficient                     0.0020
# Immigrant students - SE                              0.0007
# Father HS - coefficient                              0.0056
# Father HS - SE                                       0.0027
# Mother employed - coefficient                        0.0117
# Mother employed - SE                                 0.0035
# Missing data on father's education - coefficient    -0.0271
# Missing data on father's education - SE              0.0057
# Missing data on mother's occupation - coefficient   -0.0316
# Missing data on mother's occupation - SE             0.0054
# Missing data on country of origin - coefficient     -0.0178
# Missing data on country of origin - SE               0.0026

# %% [markdown]
# Figure E5 illustrates the monitoring effect on socioeconomic status variables. First, the presence of monitors tends to decrease observations around zero. This reinforces the hypothesis that differences in demographic covariate means are due to inaccurate reporting, which not too seldomly appears to take the form of reporting zero observations. This feature can be seen especially well with the distribution of reported percentages of immigrant pupils in the South. Note also the impact on regional differences, especially for the share of students with employed mothers: the monitoring effect disproportionately affects the distribution of Southern Italy, meaning that the 30 p.p. gap with Northern Italy shrinks to a 25 p.p. gap. As a consequence, students in the South appear to have a weaker socioeconomic background than they really have, at least as proxied by these observables.

# %% [markdown]
# #### Figure E5: Monitoring and Data on Student Background

# %%
plot_monitor_demodata(df)

# %% [markdown]
# Table 5 displays the effect of monitoring on the share of compromised scores (the second endogenous variable) and on the test scores themselves (the outcome), which have been regressed on the controls included in the interacted model discussed in Section 3. The assignment of monitors reduces score manipulation by 1 p.p. in the North/Center and by about 5 to 6 p.p. in the South, effectively halving the phenomenon (see the dependent variable mean). Monitors are also associated with a decline in test scores of $0.054\sigma$ to $0.075\sigma$ in Northern and Central Italy, of $0.131\sigma$ to $0.180\sigma$ in Southern Italy.

# %% [markdown]
# #### Table 5 - Monitoring Effects on Score Manipulation and Test Scores

# %%
create_table5(df)
# Out:
#                                                        Score manipulation  \
#                                                                     Italy
# Panel A. Math     Monitor at institution - coefficient             -0.029
#                   Monitor at institution - SE                       0.002
#                   Dependent variable mean                           0.064
#                   Dependent variable mean                           0.246
#                   Observations                                     139996
# Panel B. Language Monitor at institution - coefficient             -0.025
#                   Monitor at institution - SE                       0.002
#                   Dependent variable mean                           0.055
#                   Dependent variable mean                           0.229
#                   Observations                                     140003
#
#                                                                              \
#                                                        North/Center   South
# Panel A. Math     Monitor at institution - coefficient       -0.010  -0.062
#                   Monitor at institution - SE                 0.001   0.004
#                   Dependent variable mean                     0.020   0.139
#                   Dependent variable mean                     0.139   0.346
#                   Observations                                87491   52505
# Panel B. Language Monitor at institution - coefficient       -0.012  -0.047
#                   Monitor at institution - SE                 0.001   0.004
#                   Dependent variable mean                     0.023   0.110
#                   Dependent variable mean                     0.149   0.313
#                   Observations                                87493   52510
#
#                                                        Test scores  \
#                                                              Italy
# Panel A. Math     Monitor at institution - coefficient      -0.112
#                   Monitor at institution - SE                0.006
#                   Dependent variable mean                    0.007
#                   Dependent variable mean                    0.637
#                   Observations                              140010
# Panel B. Language Monitor at institution - coefficient      -0.081
#                   Monitor at institution - SE                0.004
#                   Dependent variable mean                    0.010
#                   Dependent variable mean                    0.523
#                   Observations                              140010
#
#
#                                                        North/Center   South
# Panel A. Math     Monitor at institution - coefficient       -0.075  -0.180
#                   Monitor at institution - SE                 0.005   0.012
#                   Dependent variable mean                    -0.074   0.141
#                   Dependent variable mean                     0.502   0.796
#                   Observations                                87498   52512
# Panel B. Language Monitor at institution - coefficient       -0.054  -0.131
#                   Monitor at institution - SE                 0.004   0.009
#                   Dependent variable mean                    -0.005   0.035
#                   Dependent variable mean                     0.428   0.649
#                   Observations                                87498   52512

# %%
print('There are',len(df[df['o_math']==1]),'classes whose institution has been monitored, but only',
      len(df[df['sampled_ital']==1]),'classes that were monitored themselves. Classes monitored in math were also monitored in Italian:',
      df[df['sampled_math']==1].equals(df[df['sampled_ital']==1]))
# Out:
# There are 34325 classes whose institution has been monitored, but only 9630 classes that were monitored themselves. Classes monitored in math were also monitored in Italian: True

# %% [markdown]
# Figure E6 compares the distribution of test scores of classes that were and were not monitored (left column), and of classes whose institution had a monitor present and not. Although the monitoring effect is unsurprisingly greater when the class itself is visited by an outside proctor, it appears that all classes of a monitored institution are affected. As foreshadowed by the regression estimates, the most impressive change can be seen for math test scores in the South, with a distribution that completely changes shape (apart from lower test score means, the variance and the positive skewness shrink).

# %% [markdown]
# #### Figure E6: Monitoring and Test Scores

# %%
plot_monitor_testscores(df)

# %% [markdown]
# In sum, the assignment of monitors is, if not perfectly, as good as random, with differences in observables due to inaccurate reporting by the school staff. Table 5 shows that the presence of monitors does deter score manipulation and thereby influences test scores themselves, suggesting that it is a valid instrument.

# %% [markdown]
# ## 4.5. Final Model

# %% [markdown]
# #### Table 6

# %%
create_table6(df)
# Out:
#                                          Math                      Language  \
#                                         Italy North/Center   South    Italy
# Class size x Monitor - coefficient     -0.035       -0.039  -0.035   -0.031
# Class size x Monitor - SE               0.024        0.021   0.060    0.019
# Class size x No monitor - coefficient  -0.066       -0.042  -0.143   -0.042
# Class size x No monitor - SE            0.021        0.018   0.053    0.016
# Monitor - coefficient                  -0.174       -0.082  -0.395   -0.103
# Monitor - SE                            0.041        0.038   0.096    0.033
# Observations                           140010        87498   52512   140010
#
#
#                                       North/Center   South
# Class size x Monitor - coefficient          -0.021  -0.048
# Class size x Monitor - SE                    0.017   0.048
# Class size x No monitor - coefficient       -0.021  -0.098
# Class size x No monitor - SE                 0.014   0.042
# Monitor - coefficient                       -0.055  -0.228
# Monitor - SE                                 0.030   0.076
# Observations                                 87498   52512

# %% [markdown]
# #### Table 7

# %%
create_table7(df)
# Out:
#                                                                      Math  \
#                                                                     Italy
# Panel A. Score manipulation Maimonides' Rule - coefficient        -0.0009
#                             Maimonides' Rule - SE                  0.0004
#                             Monitor at institution - coefficient  -0.0293
#                             Monitor at institution - SE            0.0018
#                             Observations                           139996
# Panel B. Class size         Maimonides' Rule - coefficient         0.0513
#                             Maimonides' Rule - SE                  0.0006
#                             Monitor at institution - coefficient   0.0013
#                             Monitor at institution - SE            0.0024
#                             Observations                           140010
#
#                                                                                \
#                                                                  North/Center
# Panel A. Score manipulation Maimonides' Rule - coefficient            -0.0003
#                             Maimonides' Rule - SE                      0.0002
#                             Monitor at institution - coefficient      -0.0103
#                             Monitor at institution - SE                0.0012
#                             Observations                                87491
# Panel B. Class size         Maimonides' Rule - coefficient             0.0555
#                             Maimonides' Rule - SE                      0.0008
#                             Monitor at institution - coefficient       0.0032
#                             Monitor at institution - SE                0.0027
#                             Observations                                87498
#
#                                                                            \
#                                                                     South
# Panel A. Score manipulation Maimonides' Rule - coefficient        -0.0019
#                             Maimonides' Rule - SE                  0.0009
#                             Monitor at institution - coefficient  -0.0623
#                             Monitor at institution - SE            0.0043
#                             Observations                            52505
# Panel B. Class size         Maimonides' Rule - coefficient         0.0433
#                             Maimonides' Rule - SE                  0.0011
#                             Monitor at institution - coefficient  -0.0009
#                             Monitor at institution - SE            0.0045
#                             Observations                            52512
#
#                                                                  Language  \
#                                                                     Italy
# Panel A. Score manipulation Maimonides' Rule - coefficient        -0.0008
#                             Maimonides' Rule - SE                  0.0003
#                             Monitor at institution - coefficient  -0.0246
#                             Monitor at institution - SE            0.0016
#                             Observations                           140003
# Panel B. Class size         Maimonides' Rule - coefficient            NaN
#                             Maimonides' Rule - SE                     NaN
#                             Monitor at institution - coefficient      NaN
#                             Monitor at institution - SE               NaN
#                             Observations                              NaN
#
#                                                                                \
#                                                                  North/Center
# Panel A. Score manipulation Maimonides' Rule - coefficient            -0.0003
#                             Maimonides' Rule - SE                      0.0003
#                             Monitor at institution - coefficient      -0.0120
#                             Monitor at institution - SE                0.0013
#                             Observations                                87493
# Panel B. Class size         Maimonides' Rule - coefficient                NaN
#                             Maimonides' Rule - SE                         NaN
#                             Monitor at institution - coefficient          NaN
#                             Monitor at institution - SE                   NaN
#                             Observations                                  NaN
#
#
#                                                                     South
# Panel A. Score manipulation Maimonides' Rule - coefficient        -0.0015
#                             Maimonides' Rule - SE                  0.0008
#                             Monitor at institution - coefficient  -0.0468
#                             Monitor at institution - SE            0.0038
#                             Observations                            52510
# Panel B. Class size         Maimonides' Rule - coefficient            NaN
#                             Maimonides' Rule - SE                     NaN
#                             Monitor at institution - coefficient      NaN
#                             Monitor at institution - SE               NaN
#                             Observations                              NaN

# %% [markdown]
# #### Table 8

# %%
create_table8(df)
# Out:
#                                                                 IV/2SLS  \
#                                                                   Italy
# Panel A. Math     Class size - coefficient                        0.008
#                   Class size - SE                                 0.021
#                   Score manipulation - coefficient                3.827
#                   Score manipulation - SE                         0.189
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value
#                   Observations                                   139996
# Panel B. Language Class size - coefficient                        0.012
#                   Class size - SE                                 0.017
#                   Score manipulation - coefficient                3.289
#                   Score manipulation - SE                         0.182
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value
#                   Observations                                   140003
#
#                                                                               \
#                                                                 North/Center
# Panel A. Math     Class size - coefficient                            -0.003
#                   Class size - SE                                      0.030
#                   Score manipulation - coefficient                     7.330
#                   Score manipulation - SE                              0.784
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value
#                   Observations                                         87491
# Panel B. Language Class size - coefficient                             0.005
#                   Class size - SE                                      0.020
#                   Score manipulation - coefficient                     4.496
#                   Score manipulation - SE                              0.452
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value
#                   Observations                                         87493
#
#                                                                         \
#                                                                  South
# Panel A. Math     Class size - coefficient                       0.006
#                   Class size - SE                                0.044
#                   Score manipulation - coefficient               2.880
#                   Score manipulation - SE                        0.158
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value
#                   Observations                                   52505
# Panel B. Language Class size - coefficient                       0.013
#                   Class size - SE                                0.039
#                   Score manipulation - coefficient               2.795
#                   Score manipulation - SE                        0.179
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value
#                   Observations                                   52510
#
#                                                                 IV/2SLS (overidentified)  \
#                                                                                    Italy
# Panel A. Math     Class size - coefficient                                         0.005
#                   Class size - SE                                                  0.021
#                   Score manipulation - coefficient                                 3.824
#                   Score manipulation - SE                                          0.189
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value                                              0.323
#                   Observations                                                    139996
# Panel B. Language Class size - coefficient                                         0.017
#                   Class size - SE                                                  0.017
#                   Score manipulation - coefficient                                 3.226
#                   Score manipulation - SE                                          0.178
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value                                              0.019
#                   Observations                                                    140003
#
#                                                                               \
#                                                                 North/Center
# Panel A. Math     Class size - coefficient                            -0.004
#                   Class size - SE                                      0.030
#                   Score manipulation - coefficient                     7.337
#                   Score manipulation - SE                              0.784
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value                                  0.718
#                   Observations                                         87491
# Panel B. Language Class size - coefficient                             0.005
#                   Class size - SE                                      0.019
#                   Score manipulation - coefficient                     4.480
#                   Score manipulation - SE                              0.446
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value                                  0.808
#                   Observations                                         87493
#
#                                                                         \
#                                                                  South
# Panel A. Math     Class size - coefficient                       0.001
#                   Class size - SE                                0.043
#                   Score manipulation - coefficient               2.877
#                   Score manipulation - SE                        0.158
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value                            0.521
#                   Observations                                   52505
# Panel B. Language Class size - coefficient                       0.032
#                   Class size - SE                                0.037
#                   Score manipulation - coefficient               2.723
#                   Score manipulation - SE                        0.175
#                   Class size x Score manipulation - coefficient
#                   Class size x Score manipulation - SE
#                   Overid test p-value                            0.003
#                   Observations                                   52510
#
#                                                                  IV/2SLS (overidentified-interacted)  \
#                                                                                                Italy
# Panel A. Math     Class size - coefficient                                                     0.058
#                   Class size - SE                                                              0.028
#                   Score manipulation - coefficient                                             5.680
#                   Score manipulation - SE                                                      1.423
#                   Class size x Score manipulation - coefficient                               -0.934
#                   Class size x Score manipulation - SE                                         0.709
#                   Overid test p-value                                                          0.301
#                   Observations                                                                139996
# Panel B. Language Class size - coefficient                                                     0.103
#                   Class size - SE                                                              0.027
#                   Score manipulation - coefficient                                             6.305
#                   Score manipulation - SE                                                      1.344
#                   Class size x Score manipulation - coefficient                               -1.503
#                   Class size x Score manipulation - SE                                         0.634
#                   Overid test p-value                                                          0.026
#                   Observations                                                                140003
#
#                                                                               \
#                                                                 North/Center
# Panel A. Math     Class size - coefficient                             0.048
#                   Class size - SE                                      0.050
#                   Score manipulation - coefficient                    12.413
#                   Score manipulation - SE                              6.477
#                   Class size x Score manipulation - coefficient       -2.570
#                   Class size x Score manipulation - SE                 3.187
#                   Overid test p-value                                  0.687
#                   Observations                                         87491
# Panel B. Language Class size - coefficient                             0.046
#                   Class size - SE                                      0.030
#                   Score manipulation - coefficient                     7.356
#                   Score manipulation - SE                              2.809
#                   Class size x Score manipulation - coefficient       -1.417
#                   Class size x Score manipulation - SE                 1.307
#                   Overid test p-value                                  0.629
#                   Observations                                         87493
#
#
#                                                                   South
# Panel A. Math     Class size - coefficient                        0.129
#                   Class size - SE                                 0.047
#                   Score manipulation - coefficient                4.752
#                   Score manipulation - SE                         1.124
#                   Class size x Score manipulation - coefficient  -0.939
#                   Class size x Score manipulation - SE            0.559
#                   Overid test p-value                             0.396
#                   Observations                                    52505
# Panel B. Language Class size - coefficient                        0.226
#                   Class size - SE                                 0.055
#                   Score manipulation - coefficient                6.211
#                   Score manipulation - SE                         1.416
#                   Class size x Score manipulation - coefficient  -1.687
#                   Class size x Score manipulation - SE            0.669
#                   Overid test p-value                             0.024
#                   Observations                                    52510

# %% [markdown]
# #### Table 9

# %%
create_table9(df)
# Out:
#                                                       Italy North/Center  \
# Percent in class sitting the test - coefficient      0.0000       0.0001
# Percent in class sitting the test - SE               0.0001       0.0001
# Percent in school sitting the test - coefficient     0.0001       0.0001
# Percent in school sitting the test - SE              0.0001       0.0001
# Percent in institution sitting the test - coeff...  -0.0001      -0.0001
# Percent in institution sitting the test - SE         0.0001       0.0001
# Female students - coefficient                        0.0000       0.0002
# Female students - SE                                 0.0002       0.0002
# Immigrant students - coefficient                    -0.0007      -0.0007
# Immigrant students - SE                              0.0002       0.0003
# Father HS - coefficient                              0.0006       0.0002
# Father HS - SE                                       0.0003       0.0003
# Mother employed - coefficient                        0.0012       0.0010
# Mother employed - SE                                 0.0004       0.0005
# Missing data on father's education - coefficient     0.0003       0.0015
# Missing data on father's education - SE              0.0006       0.0007
# Missing data on mother's occupation - coefficient    0.0002       0.0014
# Missing data on mother's occupation - SE             0.0006       0.0007
# Missing data on country of origin - coefficient     -0.0001      -0.0001
# Missing data on country of origin - SE               0.0002       0.0003
#
#                                                       South
# Percent in class sitting the test - coefficient      0.0000
# Percent in class sitting the test - SE               0.0001
# Percent in school sitting the test - coefficient     0.0001
# Percent in school sitting the test - SE              0.0001
# Percent in institution sitting the test - coeff...  -0.0000
# Percent in institution sitting the test - SE         0.0001
# Female students - coefficient                       -0.0002
# Female students - SE                                 0.0003
# Immigrant students - coefficient                    -0.0004
# Immigrant students - SE                              0.0001
# Father HS - coefficient                              0.0013
# Father HS - SE                                       0.0005
# Mother employed - coefficient                        0.0016
# Mother employed - SE                                 0.0006
# Missing data on father's education - coefficient    -0.0018
# Missing data on father's education - SE              0.0010
# Missing data on mother's occupation - coefficient   -0.0019
# Missing data on mother's occupation - SE             0.0010
# Missing data on country of origin - coefficient     -0.0000
# Missing data on country of origin - SE               0.0005

# %%
df['dev'] = cutoffs_center(df)
df_south = df[df.north_center ==1]
cols = df_south[['female','m_female','immigrants_broad','m_origin','dad_midedu','m_dad_edu','mom_employed','m_mom_occ']]
titles = ['Female','Female - Missing','Immigrant','Immigrant - Missing','Father HS','Father HS - Missing','Mother Employed','Mother Employed - Missing']
Tot = int(len(cols.columns))
Rows = 2
Cols = int(Tot/Rows)
Position = range(1,Tot + 1)
# df.loc[df.sampled_math ==1] 

fig = plt.figure(1)
for k in range(Tot):
    df_south['mycolumn'] = cols.iloc[:,k]
    groupp = df_south.groupby(['dev'],as_index=False)['mycolumn'].mean()
    ax = fig.add_subplot(Rows,Cols,Position[k])
    sns.scatterplot(x='dev', y='mycolumn', data=groupp, palette='pastel',color='c')
    ax.set_ylabel('')
    ax.set_xlabel('Enrollment')
    ax.set_title(titles[k])
    ax.axvline(color='r')
    ax.xaxis.set_ticks(np.arange(-12,15,3))
    ax.yaxis.set_ticks(np.arange(round(groupp['mycolumn'].mean(),2)-0.05, round(groupp['mycolumn'].mean(),2)+0.05, 0.01))
    #plt.yticks(np.arange(min(groupp['mycolumn']), max(groupp['mycolumn']), .1))
    #sns.set(style="ticks")

plt.tight_layout()
fig.set_size_inches(14,8)
plt.show()

# %% [markdown]
# ---
# # 8. References
# ---

# %% [markdown]
# * **Angrist, J. D., and Lavy, V. (1999)**. Using Maimonides' rule to estimate the effect of class size on scholastic achievement. *The Quarterly Journal of Economics, 114(2)*, 533-575.
# * **Angrist, J. D.,  Lavy, V., Leder-Luis, J., and Shany, A. (2019)**. Maimonides' Rule Redux. *American Economic Review: Insights, 1(3)*, 309-24.
# * **Averett, S. L., and McLennan, M. C. (2004)**. Exploring the effect of class size on student achievement: What have we learned over the past two decades. *International handbook on the Economics of Education, 329*, 329.
# * **Chetty, R., Friedman, J. N., Hilger, N., Saez, E., Schanzenbach, D. W., and Yagan, D. (2011)**. How does your kindergarten classroom affect your earnings? Evidence from Project STAR. *The Quarterly Journal of Economics, 126(4)*, 1593-1660.
# * **Chingos, M. M. (2012)**. The impact of a universal class-size reduction policy: Evidence from Florida's statewide mandate. *Economics of Education Review, 31(5)*, 543-562.
# * **Hoxby, C. M. (2000)**. The effects of class size on student achievement: New evidence from population variation. *The Quarterly Journal of Economics, 115(4)*, 1239-1285.
# * **Jepsen, C., and Rivkin, S. (2009)**. Class size reduction and student achievement the potential tradeoff between teacher quality and class size. *Journal of human resources, 44(1)*, 223-250.
# * **Krueger, A. B. (1999)**. Experimental estimates of education production functions. *The Quarterly Journal of Economics, 114(2)*, 497-532.
